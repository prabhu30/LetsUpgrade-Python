# %% [markdown]
# # Agenda ->
#
# 1. Completing data types
# 2. IF ELSE
# 3. Loops

# %%
# Lists

# %%
lst = [1,2,3,4,5,"hi",56.7,['a','b'],7,8,9]

# %%
lst[7][1]
# Out:
# 'b'

# %%
lst.append(7)

# %%
lst.insert(5,"Lakshmi")

# %%
lst
# Out:
# [1, 2, 3, 4, 5, 'hi', 56.7, ['a', 'b'], 7, 8, 9, 7, 7]

# %%
lst
# Out:
# ['a', 'b']

# %%
lst[-1]
# Out:
# 9

# %%
lst[-4]
# Out:
# ['a', 'b']

# %%
dit = { "Key":100, "Key1":200}

# %%
dit.get("Key")
# Out:
# 100

# %%
dit['Key1']
# Out:
# 200

# %%
bioData = {"Name":"Sujit","Age":23,"Loc":"Mumbai" }

# %%
bioData
# Out:
# {'Age': 23, 'Loc': 'Mumbai', 'Name': 'Sujit'}

# %%
bioData.get("Name")
# Out:
# 'Sujit'

# %%
bioData.keys()
# Out:
# dict_keys(['Name', 'Age', 'Loc'])

# %%
bioData.values()
# Out:
# dict_values(['Sujit', 23, 'Mumbai'])

# %%
muaskanDetails = { "Name": "Muskan", "DOB":"abc", "Loc":"Pue"}

# %%
muaskanDetails
# Out:
# {'DOB': 'abc', 'Loc': 'Pue', 'Name': 'Muskan'}

# %% [markdown]
# # Assignment 1
#
# -> Experiment with 5 List's In-built function, and post it to Github
#
# # Assignment 2
#
# -> Experiment with 5 Dict's In-Built Function, and post it to Github

# %%
# Sets

# %%
st = {"a","b", "c", 1,1,1,1,1,5,3,3,6,7,7,9,9,10}

# %%
st
# Out:
# {1, 10, 3, 5, 6, 7, 9, 'a', 'b', 'c'}

# %%
# Tuple

# %%
tup = ("LetsUpgrade")

# %%
tup
# Out:
# ('LetsUpgrade',)

# %%
del tup

# %%
tup = ("letsupgrade","Is Your Startup TOO","Help us with Sharing")

# %%
tup
# Out:
# ('letsupgrade', 'Is Your Startup TOO', 'Help us with Sharing')
