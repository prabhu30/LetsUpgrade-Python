# %%
# 1 


# !pip install emails
# Out:
# ...
#      |████████████████████████████████| 61kB 4.9MB/s
# ...
#      |████████████████████████████████| 409kB 7.5MB/s
# ...

# %%
# 2 

import emails

# %%
# 3 

#Create a Dummy Email for Demo 

# email- pythonemailsendersai@gmail.com

# Password - sakp@1896

# Turn on your less secure app access from manage account

# %%
# 4 - Get HTML MEssage online

html_msg = '''
<p><span style="font-family: Calibri, sans-serif;">Hey Boss,&nbsp;</span></p>
<p><span style="font-family: Calibri, sans-serif;">This is Saikiran from LU, my todays daily report is, -&gt;&nbsp;</span></p>
<p><span style="font-family: Calibri, sans-serif;"><br></span></p>
<p><span style="font-family: Calibri, sans-serif;">1. I did watch YT<br>2. I did some work&nbsp;</span></p>
<p><span style="font-family: Calibri, sans-serif;"><br></span></p>
<p><span style="font-family: Calibri, sans-serif;">Regards, <br>Saikiran Kishor Sondarkar </span></p>
'''

# 5 Contrust the message -> 
message = emails.html(html=html_msg,
                          subject="Daily Report - Saikrian ",
                          mail_from=('Rowdy LU', 'pythonemailsendersai@gmail.com'))

# %%
# 6 - sennd the mail 

mail_via_python = message.send(to=['lamig90472@donmah.com','sai@letsupgrade.in'], 
                               smtp={'host': 'smtp.gmail.com', 
                                     'timeout': 5,
                                    'port':587,
                                    'user':'pythonemailsendersai@gmail.com',
                                    'password':'sakp@1896',
                                    'tls':True})

# %%
#7 - Check output 

mail_via_python
# Out:
# <emails.backend.SMTPResponse status_code=250 status_text=b'2.0.0 OK  1613144552 68sm9066923pfe.33 - gsmtp'>
